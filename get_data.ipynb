# %%
import pandas as pd
import rdkit
from chembl_webresource_client.new_client import new_client
from pandas import DataFrame
import numpy as np
from rdkit import Chem

# %%
target = new_client.target
target_query = target.search('Dipeptidyl peptidase IV of human')
targets = pd.DataFrame.from_dict(target_query)

# %%
targets['target_chembl_id'][4]
# Out:
# 'CHEMBL284'

# %%
choosen_target = targets.target_chembl_id[4]
activity = new_client.activity
res = activity.filter(target_chembl_id=choosen_target).filter(standard_type="IC50")
df = pd.DataFrame.from_dict(res)
df = df.to_csv('test.csv')

# %%
df = pd.read_csv('test.csv')

# %%
df
# Out:
#       Unnamed: 0 activity_comment  activity_id activity_properties  \
# 0              0              NaN       105501                  []
# 1              1              NaN       106644                  []
# 2              2              NaN       106647                  []
# 3              3              NaN       106650                  []
# 4              4              NaN       108924                  []
# ...          ...              ...          ...                 ...
# 5045        5045              NaN     23308670                  []
# 5046        5046              NaN     23308671                  []
# 5047        5047              NaN     23308672                  []
# 5048        5048              NaN     23308673                  []
# 5049        5049              NaN     23308674                  []
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL666573  In vitro inhibition of human Dipeptidylpeptida...
# ...
